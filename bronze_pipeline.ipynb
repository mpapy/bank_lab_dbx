# %%
"""
DROP TABLE IF EXISTS raiffka_catalog.dev_bronze.customers;
DROP TABLE IF EXISTS raiffka_catalog.dev_bronze.accounts;
DROP TABLE IF EXISTS raiffka_catalog.dev_bronze.cards;
DROP TABLE IF EXISTS raiffka_catalog.dev_bronze.employees;
DROP TABLE IF EXISTS raiffka_catalog.dev_bronze.branches;
DROP TABLE IF EXISTS raiffka_catalog.dev_bronze.cities;
DROP TABLE IF EXISTS raiffka_catalog.dev_bronze.regions;
DROP TABLE IF EXISTS raiffka_catalog.dev_bronze.products;
DROP TABLE IF EXISTS raiffka_catalog.dev_bronze.merchants;
DROP TABLE IF EXISTS raiffka_catalog.dev_bronze.account_balances;
DROP TABLE IF EXISTS raiffka_catalog.dev_bronze.card_transactions;
DROP TABLE IF EXISTS raiffka_catalog.dev_bronze.financial_transactions;
"""
import dlt
from pyspark.sql.functions import current_timestamp, col, to_date, regexp_extract, from_json
from pyspark.sql.types import MapType, StringType

# Dostanu DEV nebo PROD
# dbutils.widgets.text("pipeline_env", "dev")
# env = dbutils.widgets.get("pipeline_env")
env = spark.conf.get("pipeline.env") 
catalog = "raiffka_catalog"
bronze_schema = f"{env}_bronze"

# Tabulky se snapshoty (datumové složky)
@dlt.table(name="customers_bronze", comment="Bronze table for raw Customers data")
def customers_bronze():
    path = f"/Volumes/{catalog}/landing/landing_data/customers"
    
    return (spark.readStream
            .format("cloudFiles")
            .option("cloudFiles.format", "csv")
            .option("header", "true")
            .option("multiLine", True)
            .option("quote", '"')
            .option("escape", '"')
            .load(path)
            .select("*", col("_metadata.file_path").alias("source_file"))
            .withColumn("ingestion_ts", current_timestamp())
            .withColumn("snapshot_date",
                        to_date(
                            regexp_extract(
                                col("source_file"),
                                r'/landing_data/[^/]+/(\d{4}\.\d{2}\.\d{2})/',
                                1),
                            "yyyy.MM.dd"))
           )

@dlt.table(name="accounts_bronze", comment="Bronze table for raw Accounts data")
def accounts_bronze():
    path = f"/Volumes/{catalog}/landing/landing_data/accounts"
    
    return (spark.readStream
            .format("cloudFiles")
            .option("cloudFiles.format", "csv")
            .option("header", "true")
            .option("multiLine", True)
            .option("quote", '"')
            .option("escape", '"')
            .load(path)
            .select("*", col("_metadata.file_path").alias("source_file"))
            .withColumn("ingestion_ts", current_timestamp())
            .withColumn("snapshot_date",
                        to_date(
                            regexp_extract(
                                col("source_file"),
                                r'/landing_data/[^/]+/(\d{4}\.\d{2}\.\d{2})/',
                                1),
                            "yyyy.MM.dd"))
           )

@dlt.table(name="cards_bronze", comment="Bronze table for raw Cards data")
def cards_bronze():
    path = f"/Volumes/{catalog}/landing/landing_data/cards"
    
    return (spark.readStream
            .format("cloudFiles")
            .option("cloudFiles.format", "csv")
            .option("header", "true")
            .option("multiLine", True)
            .option("quote", '"')
            .option("escape", '"')
            .load(path)
            .select("*", col("_metadata.file_path").alias("source_file"))
            .withColumn("ingestion_ts", current_timestamp())
            .withColumn("snapshot_date",
                        to_date(
                            regexp_extract(
                                col("source_file"),
                                r'/landing_data/[^/]+/(\d{4}\.\d{2}\.\d{2})/',
                                1),
                            "yyyy.MM.dd"))
           )

@dlt.table(name="employees_bronze", comment="Bronze table for raw Employees data")
def employees_bronze():
    path = f"/Volumes/{catalog}/landing/landing_data/employees"
    
    return (spark.readStream
            .format("cloudFiles")
            .option("cloudFiles.format", "csv")
            .option("header", "true")
            .option("multiLine", True)
            .option("quote", '"')
            .option("escape", '"')
            .load(path)
            .select("*", col("_metadata.file_path").alias("source_file"))
            .withColumn("ingestion_ts", current_timestamp())
            .withColumn("snapshot_date",
                        to_date(
                            regexp_extract(
                                col("source_file"),
                                r'/landing_data/[^/]+/(\d{4}\.\d{2}\.\d{2})/',
                                1),
                            "yyyy.MM.dd"))
           )

# Tabulky bez snapshotů (jedno CSV)
@dlt.table(name="branches_bronze", comment="Bronze table for raw Branches data")
def branches_bronze():
    path = f"/Volumes/{catalog}/landing/landing_data/branches"
    
    return (spark.readStream
            .format("cloudFiles")
            .option("cloudFiles.format", "csv")
            .option("header", "true")
            .option("multiLine", True)
            .option("quote", '"')
            .option("escape", '"')
            .load(path)
            .select("*", col("_metadata.file_path").alias("source_file"))
            .withColumn("ingestion_ts", current_timestamp())
           )

@dlt.table(name="cities_bronze", comment="Bronze table for raw Cities data")
def cities_bronze():
    path = f"/Volumes/{catalog}/landing/landing_data/cities"
    
    return (spark.readStream
            .format("cloudFiles")
            .option("cloudFiles.format", "csv")
            .option("header", "true")
            .option("multiLine", True)
            .option("quote", '"')
            .option("escape", '"')
            .load(path)
            .select("*", col("_metadata.file_path").alias("source_file"))
            .withColumn("ingestion_ts", current_timestamp())
           )

@dlt.table(name="regions_bronze", comment="Bronze table for raw Regions data")
def regions_bronze():
    path = f"/Volumes/{catalog}/landing/landing_data/regions"
    
    return (spark.readStream
            .format("cloudFiles")
            .option("cloudFiles.format", "csv")
            .option("header", "true")
            .option("multiLine", True)
            .option("quote", '"')
            .option("escape", '"')
            .load(path)
            .select("*", col("_metadata.file_path").alias("source_file"))
            .withColumn("ingestion_ts", current_timestamp())
           )

@dlt.table(name="products_bronze", comment="Bronze table for raw Products data")
def products_bronze():
    path = f"/Volumes/{catalog}/landing/landing_data/products"
    
    return (spark.readStream
            .format("cloudFiles")
            .option("cloudFiles.format", "csv")
            .option("header", "true")
            .option("multiLine", True)
            .option("quote", '"')
            .option("escape", '"')
            .load(path)
            .select("*", col("_metadata.file_path").alias("source_file"))
            .withColumn("ingestion_ts", current_timestamp())
           )

@dlt.table(name="merchants_bronze", comment="Bronze table for raw Merchants data")
def merchants_bronze():
    path = f"/Volumes/{catalog}/landing/landing_data/merchants"
    
    return (spark.readStream
            .format("cloudFiles")
            .option("cloudFiles.format", "csv")
            .option("header", "true")
            .option("multiLine", True)
            .option("quote", '"')
            .option("escape", '"')
            .load(path)
            .select("*", col("_metadata.file_path").alias("source_file"))
            .withColumn("ingestion_ts", current_timestamp())
           )

@dlt.table(name="account_balances_bronze", comment="Bronze table for raw Account Balances data")
def account_balances_bronze():
    path = f"/Volumes/{catalog}/landing/landing_data/account_balances"
    
    return (spark.readStream
            .format("cloudFiles")
            .option("cloudFiles.format", "csv")
            .option("header", "true")
            .option("multiLine", True)
            .option("quote", '"')
            .option("escape", '"')
            .load(path)
            .select("*", col("_metadata.file_path").alias("source_file"))
            .withColumn("ingestion_ts", current_timestamp())
           )

@dlt.table(name="card_transactions_bronze", comment="Bronze table for raw Card Transactions data")
def card_transactions_bronze():
    path = f"/Volumes/{catalog}/landing/landing_data/card_transactions"
    
    return (spark.readStream
            .format("cloudFiles")
            .option("cloudFiles.format", "csv")
            .option("header", "true")
            .option("multiLine", True)
            .option("quote", '"')
            .option("escape", '"')
            .load(path)
            .select("*", col("_metadata.file_path").alias("source_file"))
            .withColumn("ingestion_ts", current_timestamp())
           )

@dlt.table(name="financial_transactions_bronze", comment="Bronze table for raw Financial Transactions data")
def financial_transactions_bronze():
    path = f"/Volumes/{catalog}/landing/landing_data/financial_transactions"
    
    return (spark.readStream
            .format("cloudFiles")
            .option("cloudFiles.format", "csv")
            .option("header", "true")
            .option("multiLine", True)
            .option("quote", '"')
            .option("escape", '"')
            .load(path)
            .select("*", col("_metadata.file_path").alias("source_file"))
            .withColumn("ingestion_ts", current_timestamp())
           )
